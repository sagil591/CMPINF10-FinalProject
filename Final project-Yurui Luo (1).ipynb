# %%
import pandas as pd
Enrollment = pd.read_csv("Enrollment by Neighborhood 2020-21 school yr.csv")
import matplotlib.pyplot as plt

Enrollment[['neighborhood','total_students_enrolled']]

  
# creating a rank column and passing the returned rank series
Enrollment["Rank"] = Enrollment['total_students_enrolled'].rank()
  
Enrollment
  
Enrollment.sort_values("total_students_enrolled", ascending=False, inplace=True)

Enrollment

#Enrollment['total_students_enrolled'].sum()
# Out:
#        neighborhood  african_american  american_indian  \
# 107         Carrick             150.0              NaN
# 105       Brookline              78.0              NaN
# 286         Carrick              95.0              NaN
# 99        Beechview              85.0              NaN
# 284       Brookline              40.0              NaN
# ..              ...               ...              ...
# 326   North Oakland               NaN              NaN
# 336       Ridgemont               NaN              NaN
# 337     Saint Clair               NaN              NaN
# 348  Strip District               NaN              NaN
# 355        West End               NaN              NaN
#
#      asian__not_pacific_islander  hispanic  multiracial  \
# 107                         73.0      22.0         83.0
# 105                         19.0      28.0         73.0
# 286                         44.0      15.0         41.0
# 99                           NaN      85.0         40.0
# ...

# %%
# Pie chart shows top five neighborhoods who have many freshman students.
labels = 'Carrick', 'Brookline', 'Carrick', 'Beechview', 'Brookline'	
sizes = [541, 526, 378, 339, 310]
explode = (0.1, 0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # In our group, the merics are education, recreation condition, and security. Basic on these three condition and the analysis of datasets, we will to figure out top five neighbors in each analysis. There should have some overlap results from each top neighbor list. To combine each group mumbers' reults, our group will find best neighbor of Pitt.
#
# # In my part, I will do the analysis of eduation. By campared enrollment numbers of stuents, avrage test score, enrollment rate, I will figure out best top five neighborhoods who have very good eduation.
